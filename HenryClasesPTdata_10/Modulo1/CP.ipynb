# %%
import numpy as np

arr = np.zeros(3)
print(arr)
# Out:
# [0. 0. 0.]

# %%
ar = np.array([1,2,3,4,5])
print(ar[1:4])
# Out:
# [2 3 4]

# %%
import pandas as pd

data = pd.Series([0.25,0.5,0.75,1.0], index=['a','b','c','d'])
data ['b']
# Out:
# 0.5

# %%
df = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df['C'] = df['A']+ df['B']
df['C']
# Out:
# 0    5
# 1    7
# 2    9
# Name: C, dtype: int64

# %%
df['C'][1]
# Out:
# 7

# %%
data = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.iloc[2]['B']
# Out:
# 6

# %%
df.iloc[2]['B']
# Out:
# 6

# %%
dat = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}
df = pd.DataFrame(dat, index=['x', 'y', 'z'])

# %%
df.iloc[2]["A"]
# Out:
# 3

# %%
# Usando loc para acceder a un dato por etiquetas de fila y columna
print(df.loc['y', 'B'])  # Salida: 5

# Usando iloc para acceder a un dato por posición entera de fila y columna
print(df.iloc[1, 1])  # Salida: 5
# Out:
# 5
# 5

# %%
s=pd.Series([1,2,3], index=['a','b','c'])

# %%
s.iloc[1]
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

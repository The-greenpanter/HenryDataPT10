# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv',encoding='latin-1')

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %%
for i in range(5):
    line = archivo.readline()
    print(line)

# Close the file
archivo.close()
# Out:
# Código de país|Nombre del país|Región|Año|CO2 (kt)|CO2 per cápita (toneladas métricas)
#
# ABW|Aruba|América Latina y Caribe|1960||
#
# ABW|Aruba|América Latina y Caribe|1961||
#
# ABW|Aruba|América Latina y Caribe|1962||
#
# ABW|Aruba|América Latina y Caribe|1963||

# %%
import pandas as pd

df_emisiones = pd.read_csv('Emisiones_CO2.csv', encoding='latin-1', sep="|")

# %%
df_emisiones.head(10)
# Out:
#   Código de país Nombre del país                   Región   Año CO2 (kt)  \
# 0            ABW           Aruba  América Latina y Caribe  1960      NaN
# 1            ABW           Aruba  América Latina y Caribe  1961      NaN
# 2            ABW           Aruba  América Latina y Caribe  1962      NaN
# 3            ABW           Aruba  América Latina y Caribe  1963      NaN
# 4            ABW           Aruba  América Latina y Caribe  1964      NaN
# 5            ABW           Aruba  América Latina y Caribe  1965      NaN
# 6            ABW           Aruba  América Latina y Caribe  1966      NaN
# 7            ABW           Aruba  América Latina y Caribe  1967      NaN
# 8            ABW           Aruba  América Latina y Caribe  1968      NaN
# 9            ABW           Aruba  América Latina y Caribe  1969      NaN
#
#   CO2 per cápita (toneladas métricas)
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# ...

# %%
df_emisiones2 = df_emisiones.dropna(axis=0, inplace=False)
df_emisiones3 = df_emisiones.dropna(axis=1, inplace=False)

# %%
df_emisiones2
# Out:
#       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26               ABW           Aruba  América Latina y Caribe  1986   179,683
# 27               ABW           Aruba  América Latina y Caribe  1987   447,374
# 28               ABW           Aruba  América Latina y Caribe  1988   612,389
# 29               ABW           Aruba  América Latina y Caribe  1989   649,059
# 30               ABW           Aruba  América Latina y Caribe  1990  1.840,83
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
# ...

# %%
df_emisiones3
# Out:
#       Código de país Nombre del país                   Región   Año
# 0                ABW           Aruba  América Latina y Caribe  1960
# 1                ABW           Aruba  América Latina y Caribe  1961
# 2                ABW           Aruba  América Latina y Caribe  1962
# 3                ABW           Aruba  América Latina y Caribe  1963
# 4                ABW           Aruba  América Latina y Caribe  1964
# ...              ...             ...                      ...   ...
# 11122            ZWE        Zimbabue      África subsahariana  2007
# 11123            ZWE        Zimbabue      África subsahariana  2008
# 11124            ZWE        Zimbabue      África subsahariana  2009
# 11125            ZWE        Zimbabue      África subsahariana  2010
# 11126            ZWE        Zimbabue      África subsahariana  2011
#
# [11127 rows x 4 columns]

# %%
df_emisiones2.info
# Out:
# <bound method DataFrame.info of       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26               ABW           Aruba  América Latina y Caribe  1986   179,683
# 27               ABW           Aruba  América Latina y Caribe  1987   447,374
# 28               ABW           Aruba  América Latina y Caribe  1988   612,389
# 29               ABW           Aruba  América Latina y Caribe  1989   649,059
# 30               ABW           Aruba  América Latina y Caribe  1990  1.840,83
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
# ...

# %%
df_emisiones.columns
# Out:
# Index(['Código de país', 'Nombre del país', 'Región', 'Año', 'CO2 (kt)',
#        'CO2 per cápita (toneladas métricas)'],
#       dtype='object')

# %%
for columna in (df_emisiones.columns):
    
    dicc_emisiones['cod_pais' ].append(columna)
    dicc_emisiones['nom_pais' ].append(columna)
    dicc_emisiones['region' ].append(columna)
    dicc_emisiones['anio' ].append(columna)
    dicc_emisiones['co2' ].append(columna)
    dicc_emisiones['co2_percapita'].append(columna)

# %%
dicc_emisiones
# Out:
# {'cod_pais': ['Código de país',
#   'Nombre del país',
#   'Región',
#   'Año',
#   'CO2 (kt)',
#   'CO2 per cápita (toneladas métricas)'],
#  'nom_pais': ['Código de país',
#   'Nombre del país',
#   'Región',
#   'Año',
#   'CO2 (kt)',
#   'CO2 per cápita (toneladas métricas)'],
#  'region': ['Código de país',
#   'Nombre del país',
#   'Región',
#   'Año',
#   'CO2 (kt)',
#   'CO2 per cápita (toneladas métricas)'],
#  'anio': ['Código de país',
#   'Nombre del país',
#   'Región',
#   'Año',
#   'CO2 (kt)',
#   'CO2 per cápita (toneladas métricas)'],
#  'co2': ['Código de país',
#   'Nombre del país',
#   'Región',
#   'Año',
#   'CO2 (kt)',
#   'CO2 per cápita (toneladas métricas)'],
#  'co2_percapita': ['Código de país',
#   'Nombre del país',
#   'Región',
#   'Año',
#   'CO2 (kt)',
#   'CO2 per cápita (toneladas métricas)']}

# %%
df_emisiones.sort_index(inplace=True)

# %%
df_emisiones.concat()
